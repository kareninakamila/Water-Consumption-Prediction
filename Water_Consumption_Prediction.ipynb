# %% [markdown]
# #Water Consumption Prediction in Malaysia
# ##WQD7003 - Data Analytics
# ###Data Drowning - Group 5, members:
#
#
# 1.   Arun Kumar (23082194)
# 2.   Siti Nur Liyana Binti Roslan (23067122)
# 3.   Karenina Kamila (23117951)
# 4.   Looi Xue Ying (24053855)
# 5.   Rahayu Rianti (23104958)

# %% [markdown]
# ## Data Drive or Link:

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the pandas library, which is used for data manipulation and analysis.
# It provides data structures like DataFrames to handle tabular data.
import pandas as pd

#Loading Malaysia Population Data into Google Drive
population_malaysia = pd.read_csv('/content/drive/MyDrive/Data/population_malaysia.csv')
print("Population Malaysia Data:")
print(population_malaysia.head())

#Loading Malaysia Population By State Data into Google Drive
population_state = pd.read_csv('/content/drive/MyDrive/Data/population_state.csv')
print("\nPopulation State Data:")
print(population_state.head())

#Loading Malaysia Water Production Data into Google Drive
water_production = pd.read_csv('/content/drive/MyDrive/Data/water_production.csv')
print("\nWater Production Data:")
print(water_production.head())

#Loading Malaysia Water Access Data into Google Drive
water_access = pd.read_csv('/content/drive/MyDrive/Data/water_access.csv')
print("\nWater Access Data:")
print(water_access.head())

#Loading Malaysia Water Consumption Data into Google Drive
water_consumption = pd.read_csv('/content/drive/MyDrive/Data/water_consumption.csv')
print("\nWater Consumption Data:")
print(water_consumption.head())
# Out:
# Population Malaysia Data:
#          date   sex      age ethnicity  population
# 0  1970-01-01  both  overall   overall     10881.8
# 1  1970-01-01  both      0-4   overall      1702.4
# 2  1970-01-01  both      5-9   overall      1690.3
# 3  1970-01-01  both    10-14   overall      1454.7
# 4  1970-01-01  both    15-19   overall      1197.6
#
# Population State Data:
#    state        date   sex      age ethnicity  population
# 0  Johor  01/01/1970  both  overall   overall      1325.6
# 1  Johor  01/01/1970  both      0-4   overall       210.1
# 2  Johor  01/01/1970  both   05-Sep   overall       215.7
# 3  Johor  01/01/1970  both   Oct-14   overall       192.2
# 4  Johor  01/01/1970  both    15-19   overall       152.8
#
# Water Production Data:
#       state        date  value
# 0  Malaysia  2000-01-01  10184
# 1  Malaysia  2001-01-01  10432
# 2  Malaysia  2002-01-01  10737
# 3  Malaysia  2003-01-01  11047
# 4  Malaysia  2004-01-01  11410
#
# Water Access Data:
# ...

# %% [markdown]
# #CRISP-DM

# %% [markdown]
# ## Phase 1- Business Understanding
#
# 1. Determine business objectives
#   *   Background
#
#       Rapid urbanization and population growth in Malaysia have significantly impacted water demand across states. Predictive modeling of water usage based on population data is crucial for efficient resource management, addressing challenges like water scarcity and infrastructure limitations, and supporting sustainable development strategies tailored to each state's needs.
#
#   *   Business objectives
#       - To analyze the water usage against population in Malaysia
#       - To build predictive model of water consumption in Malaysia
#       - To evaluate the accuracy of the predictive model used
#
#   *   Business success criteria
#       - Achieve at least 3 models with minimum 70% accuracy in predicting water production
#       - Achieve at least 3 models with moderate to low metric errors when evaluating the water consumption model
#
# 2. Situation assessment
#   * Inventory of resources
#       - Water Resources in Malaysia:
#           - Surface Water: According to the Economic Planning Unit (2021), it is stated in Malaysia Voluntary National Review 2021 that Malaysia has abundant surface water resources, mainly from rivers (80.8%) and reservoirs (17.9%), with a significant amount of rainfall throughout the year.
#           - Major river systems: Pahang, Perak, and Rajang rivers
#           - Groundwater: Meanwhile, groundwater (1.2%) constitutes a smaller share of total water usage
#           - Mainly act as water resource in rural areas and for specific industries
#
#     - Water Demand Sectors:
#          - Domestic Use: Urban and rural populations, with increasing demand due to population growth.
#          - Agriculture: A significant sector of water consumption, especially for irrigation in rural areas and palm oil cultivation.
#          - Industrial Use: Water used in manufacturing, energy production (hydropower), and processing industries.
#          - Environmental Needs: Maintaining ecosystem health, including wetlands, forests, and biodiversity, which requires substantial water flow for preservation.
#
#   * Requirements, assumptions, and constraints
#      - Requirements
#         - Reliable Water Supply: To meet the needs of a growing population
#         - Stated by WHO (2024), the current population is around 33.40 million in 2023, projected to grow to 44.3 million by 2050.
#         - Sustainability: The long-term availability of water resources must be preserved, especially as water demand grows with urbanization and economic development.
#     - Assumptions
#         - Population Growth: Steady population growth will continue to increase overall water demand.
#         - Economic Growth: The industrial sector will expand, contributing to increased water demand.
#     - Constraints
#         - Geographic Disparities: While peninsular Malaysia is more developed, states in East Malaysia (e.g., Sabah and Sarawak) may face different water resource challenges.
#         - Climate Variability: Regional differences in rainfall, with some areas experiencing droughts and others prone to floods.
#         - Infrastructure Limitations: Aging infrastructure in certain areas and the need for investment in modernizing water distribution systems.
#
#  * Benefits
#     - Optimized resource management: by using selected model to predict water usage, we can optimize the allocation of water resources for each states and ensuring equitable access for all users
#     - Sustainable development: through identifying trends in water demands using the predictions made, we can help in mitigating the risks of water scarcity and promote sustainability
#
#  * Determine data mining goals
#     - Data mining goals
#        - Descriptive goals:
#         - Identify factor influencing water consumption
#        - Predictive goals:
#          - Forecasting water consumption trends against the population in the future
#        - Prescriptive goals:
#          - Making recommendations for optimizing water resource allocation
#     - Data mining success criteria
#         - High predictive accuracy (at least 70% accuracy)
#         - Handling large dataset efficiently (N=40k)
#         - Providing suggestion align with the business objective
#
#   * Produce project plan
#     - Initial assessment of tools and techniques
#     - Programming Language: Python
#     - Data Handling Tools: Python
#     - Visualization tools: matplotlib, seaborn
#     - Predictive Modeling: Linear Regression, Random Forest, ARIMA and LSTM

# %% [markdown]
# ## Phase 2- Data Understanding
#
# 1.   Collect data
#
#       Data is being collected and downloaded from Malaysia open-sourced data website which is open and free to use. As for predicting water consumption, we collect a few datasets which are:
#       - [Malaysia population](https://open.dosm.gov.my/data-catalogue/population_malaysia)
#       - [Malaysia population data per states](https://open.dosm.gov.my/data-catalogue/population_state)
#       - [Malaysia water production by state data](https://open.dosm.gov.my/data-catalogue/water_production)
#       - [Malaysia water consumption data](https://data.gov.my/data-catalogue/water_consumption)
#       - [Access Treated Water data](https://data.gov.my/data-catalogue/water_access)

# %% [markdown]
# 2.   Describe Data
#
#       Data description of 5 dataset that have been collected, downloaded from DOSM web as shows as below:

# %%
# Describe data: this command can shows more data in those datasets and also the count of rows and columns

import pandas as pd

print(population_malaysia)
print()
print(population_state)
print()
print(water_production)
print()
print(water_consumption)
print()
print(water_access)
# Out:
#              date   sex      age         ethnicity  population
# 0      1970-01-01  both  overall           overall     10881.8
# 1      1970-01-01  both      0-4           overall      1702.4
# 2      1970-01-01  both      5-9           overall      1690.3
# 3      1970-01-01  both    10-14           overall      1454.7
# 4      1970-01-01  both    15-19           overall      1197.6
# ...           ...   ...      ...               ...         ...
# 17011  2024-01-01  male      85+        bumi_other        10.0
# 17012  2024-01-01  male      85+           chinese        14.9
# 17013  2024-01-01  male      85+            indian         4.4
# 17014  2024-01-01  male      85+     other_citizen         0.6
# 17015  2024-01-01  male      85+  other_noncitizen        11.7
#
# [17016 rows x 5 columns]
#
#                  state        date   sex      age         ethnicity  \
# 0                Johor  01/01/1970  both  overall           overall
# ...

# %% [markdown]
#     The original datasets contain:
#         1. Malaysia population has 17,016 rows with 5 (five) columns: date, sex, age, ethnicity, and population.
#         2. Malaysia population data per states has 257.295 rows with 6 (six) columns: date, state, sex, age, ethnicity, and population.
#         3. Malaysia water production by state has 345 rows with 3 (three) columns: date, state, and value.
#         4. Malaysia water consumption data has 600 rows with 4 (four) columns: state, sector, date, and water consumption.
#         5. Malaysia access to treated water by state and strata has 1,035 rows with 4 (four) columns: date, state, strata, and proportion.
#     The population data periode from 1970 to 2024 (55 years), as for water production and access treated water data from 2000 to 2022 and water consumption data from 2003 to 2022.

# %% [markdown]
# 3. Explore Data

# %%
#a. Explore dataset: example more explore dataset
rows, columns = population_malaysia.shape
print('Population Malaysia dataset:')
print("Number of rows:", {rows})
print("Number of columns:", columns)
print()

rows2, columns2 = population_state.shape
print('Population State in Malaysia dataset:')
print("Number of rows:", {rows2})
print("Number of columns:", columns2)
print()

rows3, columns3 = water_production.shape
print('Water Production dataset:')
print("Number of rows:", {rows3})
print("Number of columns:", columns3)
print()

rows4, columns4 = water_consumption.shape
print('Water Consumption dataset:')
print("Number of rows:", {rows4})
print("Number of columns:", columns4)
print()

rows5, columns5 = water_access.shape
print('Water Access dataset:')
print("Number of rows:", {rows5})
print("Number of columns:", columns5)
print()
# Out:
# Population Malaysia dataset:
# Number of rows: {17016}
# Number of columns: 5
#
# Population State in Malaysia dataset:
# Number of rows: {257295}
# Number of columns: 6
#
# Water Production dataset:
# Number of rows: {345}
# Number of columns: 3
#
# Water Consumption dataset:
# Number of rows: {600}
# Number of columns: 4
#
# Water Access dataset:
# Number of rows: {1035}
# Number of columns: 4

# %%
#b. Explore data: summary of population dataset
population_malaysia.describe()
# Out:
#          population
# count  17016.000000
# mean     542.242096
# std     1863.186659
# min        0.200000
# 25%       24.200000
# 50%      111.250000
# 75%      390.650000
# max    34058.800000

# %%
#c. Explore data: summary of water consumption dataset
import pandas as pd
water_consumption.describe()
# Out:
#              value
# count   600.000000
# mean    636.530000
# std    1224.221968
# min       7.000000
# 25%     150.000000
# 50%     248.500000
# 75%     478.750000
# max    7540.000000

# %%
#d. Explore Data Frame info for Population Malaysia
import matplotlib.pyplot as plt

# Assigning data population malaysia to df
#population_malaysia['date'] = pd.to_datetime(population_malaysia['date'])
population_malaysia['date'] = pd.to_datetime(population_malaysia['date'])
df = population_malaysia

# Filtered data in population malaysia, only data from 2003-2022, sex=both male also female, age and ethnicity is overall
#the result can be 20 rows
filtered_df = (df[(df['date'] >= '2003') & (df['date'] <= '2022') & (df['sex']=='both') & (df['ethnicity']=='overall') & (df['age']=='overall')])

# Convert date column to datetime
filtered_df['date'] = pd.to_datetime(filtered_df['date'])

# Plotting population total for filtered years to know the population trend over the period years
plt.figure(figsize=(12, 6))
plt.plot(filtered_df['date'], filtered_df['population'], marker='o', linestyle='-', color='r')
plt.title("Malaysia Population Trend (2003-2022)")
plt.xlabel("Year")
plt.ylabel("Population (Thousand)")
plt.grid(True)
plt.show()
# Out:
# <ipython-input-4-ade8fd5ef8a5>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = pd.to_datetime(filtered_df['date'])

# %%
#e. Explore Data Frame info for Water Population Malaysia
# Assigning data population malaysia to df
water_production['date'] = pd.to_datetime(water_production['date'])
df3 = water_production

# Filtered data in water productuon, only data from 2003-2022, to make standardize using the same period of data
filtered_df3 = (df3[(df3['date'] >= '2003') & (df3['date'] <= '2022') & (df3['state']=='Malaysia')])

# Plotting population total for filtered years to know the population trend over the period years
plt.figure(figsize=(12, 6))
plt.plot(filtered_df3['date'], filtered_df3['value'], marker='o', linestyle='-', color='b')
plt.title("Water Production Trend (2003-2022)")
plt.xlabel("Year")
plt.ylabel("Production Water (Thousand)")
plt.grid(True)
plt.show()

# %%
#f. Assigning data water consumption malaysia to df4
water_consumption['date'] = pd.to_datetime(water_consumption['date'])
df4 = water_consumption

# Filtered data in water productuon, only data from 2003-2022, to make standardize using the same period of data
filtered_df4 = (df4[(df4['date'] >= '2003') & (df4['date'] <= '2022') & (df4['state']=='Malaysia')])
consume_sum_year = filtered_df4.groupby(['state', 'date'])['value'].sum().reset_index()
#print(filtered_df4)
# Plotting population total for filtered years to know the population trend over the period years
plt.figure(figsize=(12, 6))
plt.plot(consume_sum_year['date'], consume_sum_year['value'], marker='o', linestyle='-', color='b')
plt.title("Water Consumption Trend (2003-2022)")
plt.xlabel("Year")
plt.ylabel("Consumption (Thousand)")
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Describe Data
#
#     To check the data quality and is there missing values or not per dataset

# %%
# Describe Data
import pandas as pd

# To check Null or Missing Value in the dataset, we can use .info
# It shows the table and column information, it is non-null so the columns and rows have values
print(population_malaysia.info())
print()
print(population_state.info())
print()
print(water_production.info())
print()
print(water_consumption.info())
print()
print(water_access.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17016 entries, 0 to 17015
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        17016 non-null  datetime64[ns]
#  1   sex         17016 non-null  object
#  2   age         17016 non-null  object
#  3   ethnicity   17016 non-null  object
#  4   population  17016 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 664.8+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257295 entries, 0 to 257294
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   state       257295 non-null  object
#  1   date        257295 non-null  object
#  2   sex         257295 non-null  object
#  3   age         257295 non-null  object
#  4   ethnicity   257295 non-null  object
#  5   population  257295 non-null  float64
# dtypes: float64(1), object(5)
# ...

# %% [markdown]
# ## Phase 3- Data Preparation
#
#
# 1.   Select data: using population by state, water production, water consumption and water access.
# 2.   Clean data: data is already being cleaned.
# 3.   Construct data
# 4.   Integrate data
# 5.   Format data
#
# Step 3-5 will be continued in the pre-processing process.

# %% [markdown]
# ## Phase 4- Modeling
#   * Select modeling technique
#       - Modeling technique : it is using patterns from past models and generating forecasts in the future.
#       - The ARIMA model is chosen as it:
#         - Relies on past patterns to forecast future values (autoregression)
#         - Removes trends or seasonality to make the data stable over time (integration)
#         - Accounts for errors in past predictions to refine future forecasts (moving average)
#       - Modeling assumptions:
#         - Stationarity: A time series is said to be stationary if its mean, variance, and autocorrelation do not change over time
#         - Linearity: ARIMA assumes that the relationships between the variables are linear.
#         - Independence of Residuals: The errors (residuals) should be uncorrelated (white noise)
#
#    - The LSTM model is chosen as it:
#        - Specifically designed to remember long-term dependencies in sequential data
#        - Can scale to large datasets and make predictions based on big volumes of data
#        - Can learn these seasonal patterns and make accurate predictions for future periods
#    - Modelling assumptions:
#        - Temporal dependencies in data as LSTM assumes that past values have an impact on future values
#        - Relies heavily on the features provided for training
#        - Assumes that external features remain relatively stable over time or that their impact on water consumption is consistent
#
#   * Generate test design
#       - Test design
#           - Scope: Forecast total water usage across Malaysia for one year (2023)
#           - Split Data:
#             - Training set: For model fitting (data from 2003–2020)
#             - Test set: For validation and comparison against known values to assess model’s accuracy (2021–2022)
#           - Predict the past water usage below 2022/ or split 80% data for training, 20% for test
#
#   * Build model
#       - Stationarity Check:
#         - Plot water usage over time to observe trends or seasonality.
#         - Use the Augmented Dickey-Fuller (ADF) test to check for stationarity.
#         - Apply differencing (first or second order) if needed.
#       - Parameter Identification:
#         - Use ACF (Autocorrelation Function) to identify q (Moving Average).
#         - Use PACF (Partial Autocorrelation Function) to identify p (Autoregression).
#         - Determine d (degree of differencing) to make the series stationary.
#
#     * Assess model
#       - Model assessment
#         - Diagnostics:
#         - Plot residuals to ensure they are white noise (no patterns).
#         - Check ACF/PACF of residuals for no significant lags.
#         - Goodness-of-Fit Metrics:
#         - Akaike Information Criterion (AIC): Lower values indicate better fit.
#         - Bayesian Information Criterion (BIC): Helps prevent overfitting.
#       - Revised parameter settings
#         - Poor residual diagnostics.
#         - High forecast error metrics.
#         - Seasonal adjustments if needed.

# %% [markdown]
# ## Phase 5- Evaluation
#
#   * Evaluate results
#       - Make an assessment of data mining results based with respect to business success criteria by using Metric errors.
#       - Metric errors : mean absolute error (MAE), mean squared error (MSE), root mean squared error (RMSE) and R-squared (R²)
#
#             - Mean Absolute Error (MAE): mae = mean_absolute_error(actual_value, predicted_value)
#
#             - Mean Squared Error (MSE)
#             mse = mean_squared_error(actual_value, predicted_value)
#
#             - Root Mean Squared Error (RMSE)
#             rmse = np.sqrt(mse)
#
#             - R-squared (R²)
#             r2 = r2_score(actual_value, predicted_value)
#
#       - Accuracy: Evaluate each metric's value to ensure that predictions are as close as possible to actual water usage data. High accuracy in the predictive model supports the business goal of planning and managing future water demands efficiently.
#
#       - Summary of desired metrics:
#         - MAE: lower values are better (closer to 0 indicates better fit).
#         - MSE: lower values are better (closer to 0 indicates better fit).
#         - RMSE: lower values are better (closer to 0 indicates better fit).
#         - R²: higher values are better (closer to 1 indicates better fit).
#
# * Review Process
#   - To ensure the quality of the data mining results remains assured, we will do a thorough review of the data mining engagement in order to determine if there is any important factor or task that has somehow been overlooked.
#   - Conduct a thorough review of every stage from data preparation to model building to ensure no critical tasks or influencing factors are missed. Reevaluate if additional data or modeling techniques could improve prediction accuracy or insight.
#   - Ensure that the data mining process is aligned with CRISP-DM best practices, addressing any gaps in data quality or feature selection that may impact final predictions.
#
# * Determine next steps
#   - From the data mining results obtained, we would be able to provide suggestions on improving water resources management for sustainability usage.
#   - Based on the results, we will recommend ways to improve water management in Malaysia. For example, if water use is high in certain areas, we can recommend suitable water-saving initiatives, such as promoting efficient irrigation in agriculture or encouraging households to save water. We can also recommend adjustments to water allocations during peak periods to ensure adequate supplies for all areas, especially during dry seasons.
#   - Since there are remaining data resources unused from the dataset, perhaps a further in depth analysis could be made to bring a deeper insight in order to improve water resource management in Malaysia.
#   - Since some data remain unused, we plan to analyze further to gain more insights. For example, we can look at how different industries (agriculture, manufacturing, etc.)  use water. By examining the water use patterns in these sectors, we can identify areas of inefficiency or excess. Likewise, we can analyze how water resources are managed in different regions (urban vs rural). This will help us make specific recommendations for water-saving measures (improve agricultural irrigation technology or manufacturing water recycling programs) in those sectors or regions.
#   - Based on the assessment results, refine the model by incorporating additional features such as economic indicators (GDP growth, industrial activity, seasonal variations (dry and wet seasons) and climate data (temperature, rainfall pattern). This could improve the model’s predictive accuracy and robustness, allowing it to better respond to real-world variables that affect water consumption. (It would involve using models like SARIMA or ARIMAX) which can handle seasonality or include external data as inputs.

# %% [markdown]
# Phase 6- Deployment
#
#   Our plan for model deployment is using IPython notebook and GitHub to share our data mining result

# %% [markdown]
# # Data Pre-processing + add on flow chart for data preparation

# %%
# Before any further analysis, we check for missing values across datasets

# Check for missing values in each dataset
print(population_malaysia.isnull().sum())
print(population_state.isnull().sum())
print(water_production.isnull().sum())
print(water_access.isnull().sum())
print(water_consumption.isnull().sum())
# Out:
# date          0
# sex           0
# age           0
# ethnicity     0
# population    0
# dtype: int64
# state         0
# date          0
# sex           0
# age           0
# ethnicity     0
# population    0
# dtype: int64
# state    0
# date     0
# value    0
# dtype: int64
# state         0
# strata        0
# date          0
# proportion    0
# dtype: int64
# state     0
# sector    0
# date      0
# value     0
# dtype: int64

# %% [markdown]
# The output shows that there are no missing values in any of the columns in our datasets.

# %%
# Convert 'date' columns to datetime format for accurate data analysis
population_malaysia['date'] = pd.to_datetime(population_malaysia['date'])
population_state['date'] = pd.to_datetime(population_state['date'])
water_access['date'] = pd.to_datetime(water_access['date'])
water_consumption['date'] = pd.to_datetime(water_consumption['date'])
water_production['date'] = pd.to_datetime(water_production['date'])

# %%
# Convert columns to appropriate data types if necessary
water_access['proportion'] = pd.to_numeric(water_access['proportion'], errors='coerce')
water_consumption['value'] = pd.to_numeric(water_consumption['value'], errors='coerce')
water_production['value'] = pd.to_numeric(water_production['value'], errors='coerce')

# merge all datasets on 'date' and 'state'
data = pd.merge(water_consumption, water_access, on=['date', 'state'], how='inner')
data = pd.merge(data, population_state, on=['date', 'state'], how='inner')
data = pd.merge(data, water_production, on=['date', 'state'], how='inner')

# rename 'value_x' and 'value_y'
data = data.rename(columns={'value_x': 'water_consumption', 'value_y': 'water_production'})

# Check for duplicates or any issues after merging
print("\nDuplicate Records:")
print(data.duplicated().sum())

# Drop duplicate rows
data.drop_duplicates(inplace=True)
# Out:
# Duplicate Records:
# 0

# %% [markdown]
# 0 means that there are no duplicate rows in our merged dataset after merging the three datasets on date and state.

# %% [markdown]
# The flow chart of our data pre-processing:

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis
#
# To measure the mean, median, mode of one variable. In this case, to measure population, water consumption, water production and water access proportion.

# %%
# Filter the data and use aggregate data only
data['year'] = data['date'].dt.year
filter_model_data = data[(data["strata"] == "overall") & (data["sector"] == "domestic") & (data['age'] =='overall') & (data['ethnicity'] =='overall')& (data['sex'] =='both') ]
filter_model_data = filter_model_data.groupby('year').sum(numeric_only=True)

# %%
# To describe the mean, min, max, etc
data[['water_consumption', 'water_production', 'population', 'proportion']].describe()
# Out:
#        water_consumption  water_production     population     proportion
# count      670320.000000     670320.000000  670320.000000  670320.000000
# mean          340.994643       1072.875000      39.799389      94.252024
# std           372.696303       1026.641749     182.024959      11.636059
# min             7.000000         34.000000       0.000000      52.000000
# 25%           135.000000        490.000000       0.300000      96.000000
# 50%           230.500000        883.500000       3.200000      99.500000
# 75%           421.250000       1272.000000      22.900000     100.000000
# max          2294.000000       5116.000000    7050.300000     100.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Water Consumption

# %%
# visualize using histogram of water consumption
sns.histplot(filter_model_data['water_consumption'])

# histogram setting
plt.title('Histogram of Water Consumption')
plt.xlabel('Water Consumption')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplots to check for distribution pattern of water consumption
sns.boxplot(x=data['water_consumption'])
plt.title('Boxplot of Water Consumption')
plt.show()

# %%
# To check skewness and kurtosis
from scipy.stats import skew, kurtosis

print("Skewness of Water Consumption:", skew(filter_model_data['water_consumption']))
print("Kurtosis of Water Consumption:", kurtosis(filter_model_data['water_consumption']))
# Out:
# Skewness of Water Consumption: 0.044270702441782286
# Kurtosis of Water Consumption: -0.8279373258015235

# %% [markdown]
# **Summary:**
# The Skewness of Water Consumption is positive value, slightly skew to the right. As it is very close to 0, indicating that the distribution of water consumption is nearly symmetric.
#
# The kurtosis value is -0.828, which means has lighter tails than normal, so there are fewer extreme values. But It can be ignored as the distribution almost normal and skewness near 0.

# %% [markdown]
# 2. Water Access Proportion

# %%
# visualize using histogram of proportion
sns.histplot(filter_model_data['proportion'])

# histogram setting
plt.title('Histogram of Water Access Proportion')
plt.xlabel('Proportion')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplots to check for distribution pattern proportion water access
sns.boxplot(x=data['proportion'])
plt.title('Boxplot of Water Access Proportion')
plt.show()

# %%
# To check skewness and kurtosis
from scipy.stats import skew, kurtosis

print("Skewness of Proportion Water Access:", skew(filter_model_data['proportion']))
print("Kurtosis of Proportion Water Access:", kurtosis(filter_model_data['proportion']))
# Out:
# Skewness of Proportion Water Access: -1.2865315661856795
# Kurtosis of Proportion Water Access: 0.7440645323655204

# %% [markdown]
# **Summary:** it shows that almost most states in Malaysia have well establised water access with mostly of the proportion has over 1,300 in 8 times. Some of its has lower water access.
#
# Observing the data, we find out that due to newly formed state in Malaysia, some states may not have entries for certain years, resulting in gaps. However, there is evidence from latest year data that improvement has been made for access water.

# %% [markdown]
# 3. Water Production

# %%
# Visualize using histogram of water production
sns.histplot(filter_model_data['water_production'])

# Histogram name
plt.title('Histogram of Water Production')
plt.xlabel('Water Production')
plt.ylabel('Frequency')
plt.show()

# %%
# BoxPlot Water Production
sns.boxplot(x=data['water_production'])
plt.title('Boxplot of Water Production')
plt.show()

# %%
# To check skewness and kurtosis
from scipy.stats import skew, kurtosis

print("Skewness of Proportion Water Production:", skew(filter_model_data['water_production']))
print("Kurtosis of Proportion Water Production:", kurtosis(filter_model_data['water_production']))
# Out:
# Skewness of Proportion Water Production: -0.13893309936841042
# Kurtosis of Proportion Water Production: -1.2340603168046003

# %% [markdown]
# The skewness for water production is in negative value, indicating a mild left skew, which is left tail longer than right. The kurtosis shows platykurtic distribution, it has lighter tails and later flatter than a normal distribution.
#
# Observing the data, there is slightly decrease of water production in some states in some years due to extreme weather conditions. However, most of states produce water relatively consistent or increasing. Furthermore, to check if there any extreme outliers, we use quartile 1 and 3 to calculate interquartile range and multiply of 1.5 to define lower and upper bounds. As min and max within these bounds, the data shows no extreme outliers, suggesting the production levels across states are fairly stable.

# %%
# Calculate summary statistics
Q1 = filter_model_data['water_production'].quantile(0.25)
Q3 = filter_model_data['water_production'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier boundaries to checl if there any extreme outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Min: {filter_model_data['water_production'].min()}")
print(f"Max: {filter_model_data['water_production'].max()}")

print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
# Out:
# Min: 11047
# Max: 18828
# Lower Bound: 7378.0
# Upper Bound: 22680.0

# %% [markdown]
# 4. Population

# %%
# visualize using histogram of population
sns.histplot(filter_model_data['population'])

# Histogram name
plt.title('Population in Malaysia')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %%
# Linechart Population of Malaysia
sns.lineplot(x=filter_model_data.index, y=filter_model_data['population'])
plt.title('Population Trend in Malaysia')
plt.xlabel('Year')
plt.ylabel('Population (Thousand)')
plt.xticks(ticks=filter_model_data.index, labels=filter_model_data.index.astype(int), rotation=45)

plt.show()

# %% [markdown]
# **Summary**: Over the year, Malaysia's population has increased from 2003 to 2019. However there is slightly declined in 2020 during Covid-19 also potentially decreasing in birth-rate. The following years, the population is slightly increased.

# %% [markdown]
# ## Bivariate Analysis
# After preprocessing, we conduct EDA to understand the data distributions, relationships, and detect any outliers or anomalies. Visualizations like histograms, box plots, and correlation matrices are used to display our findings.

# %% [markdown]
# 1. General Data Summary

# %%
# 1. General Data Summary
print("\nData Summary:")
print(data.describe())
# Out:
# Data Summary:
#                       date  water_consumption     proportion     population  \
# count               670320      670320.000000  670320.000000  670320.000000
# mean   2012-07-02 00:00:00         340.994643      94.252024      39.799389
# min    2003-01-01 00:00:00           7.000000      52.000000       0.000000
# 25%    2007-10-01 18:00:00         135.000000      96.000000       0.300000
# 50%    2012-07-02 00:00:00         230.500000      99.500000       3.200000
# 75%    2017-04-02 06:00:00         421.250000     100.000000      22.900000
# max    2022-01-01 00:00:00        2294.000000     100.000000    7050.300000
# std                    NaN         372.696303      11.636059     182.024959
#
#        water_production           year
# count     670320.000000  670320.000000
# mean        1072.875000    2012.500000
# min           34.000000    2003.000000
# 25%          490.000000    2007.750000
# 50%          883.500000    2012.500000
# ...

# %% [markdown]
# 2. Distribution of Population in Malaysia over the years

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='population', data=population_malaysia, label='Overall Population')
plt.title('Population in Malaysia Over Time')
plt.xlabel('Year')
plt.ylabel('Population (Thousand)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Summary:** The population surge in recent decades suggests increasing demand for resources, which is relevant for modeling water usage. The anomaly in the 1980s warrants further investigation to ensure accurate data.

# %% [markdown]
# 3. Population in Malaysia by State

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x='state', y='population', data=data)
plt.title("Population by State in Malaysia")
plt.xlabel("State")
plt.ylabel("Population (Thousand)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Summary:** The chart shows population distribution by state in Malaysia. Selangor has the highest population, followed by Johor, Sarawak, and Sabah. States like Perlis, Melaka, and W.P. Labuan have significantly smaller populations. This highlights uneven population distribution, with urban and industrialized states like Selangor having larger populations.

# %% [markdown]
# 4. Distribution of Water Access across Malaysia over the years

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='proportion', data=water_access, label='Water Access Proportion')
plt.title('Water Access Proportion Over Time')
plt.xlabel('Year')
plt.ylabel('Water Access Proportion (%)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Summary:** The graph shows the proportion of water access in Malaysia over time. Water access has generally increased, starting around 92% in 2000 and reaching above 96% in recent years. However, there are fluctuations, including a notable dip around 2008. The uncertainty band narrows over time, indicating improved confidence in the data in later years.

# %% [markdown]
# 5. Water Consumption vs. Water Production over time

# %%
plt.figure(figsize=(12, 6))

# Water Consumption
sns.lineplot(x='date', y='water_consumption', data=data, label='Water Consumption')

# Water Production
sns.lineplot(x='date', y='water_production', data=data, label='Water Production')

plt.title('Water Consumption vs Water Production Over Time')
plt.xlabel('Year')
plt.ylabel('Water Consumption / Production (Thousand Liters)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# 6. State-wise Water Consumption vs. Production (Bar Plot)

# %%
# Group by 'state' and sum the values for water consumption and water production
state_data = data.groupby('state')[['water_consumption', 'water_production']].sum()

# Plot bar chart
state_data.plot(kind='bar', figsize=(12, 6), title='Water Consumption and Production by State')
plt.xlabel('State')
plt.ylabel('Total Water Consumption / Production (Million Liters)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 7. Water Production Deficit

# %%
data['production_deficit'] = data['water_production'] - data['water_consumption']

plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='production_deficit', data=data)
plt.title('Water Production Deficit Over Time')
plt.xlabel('Year')
plt.ylabel("Water Production Deficit (Thousand Liters)")
plt.xticks(rotation=45)
plt.show()

# %%
# 8. Water Consumption per Capita (Consumption per Population)
# Ensure the 'population' column exists in the final merged dataset
if 'population' in data.columns:
    # Calculate water consumption per capita
    data['consumption_per_capita'] = data['water_consumption'] / data['population']

    # Plot the line chart for water consumption per capita over time
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='date', y='consumption_per_capita', data=data)
    plt.title('Water Consumption per Capita Over Time')
    plt.xlabel('Year')
    plt.ylabel('Water Consumption per Capita (Thousand Liters)')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
# Correlation Between Numeric Variables
# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Handle missing values (drop or fill)
numeric_data = numeric_data.dropna()

# Generate the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Key Insights from the correlation graph
# *  **Water Consumption and Water Production (0.93):**
# There’s a strong positive correlation, meaning that when water consumption increases, water production tends to increase as well. This makes sense because more water usage usually leads to more water being produced or supplied.
#
# *   **Water Consumption and Production Deficit (0.84):**
# Another strong positive correlation, which suggests that when water consumption goes up, the production deficit (the gap between production and consumption) also increases. So, if water consumption is higher than production, the deficit becomes larger.
#
# *   **Water Production and Production Deficit (0.98):** This is an extremely strong positive correlation. As water production increases, the production deficit decreases. Essentially, more water production reduces the gap between what is needed and what is produced.
#
# *   **Water Consumption and Consumption per Capita (0.21):** A weak positive correlation, meaning that overall water consumption and water consumption per person (per capita) are slightly related, but not strongly
#
# *   **Water consumption has a weak correlation with population (0.14) and proportion (0.18).**
# Population and proportion have weak relationships with all other variables, suggesting they might not be significant drivers of the patterns you see in water consumption and production.
#
#
# Summary
# **Main Point** - the most significant relationships are between water consumption, water production, and production deficit. As water consumption goes up, production must increase to prevent a larger deficit.
#
# **Actionable Insight** - to reduce the water production deficit, focusing on increasing water production is key. Understanding the balance between water consumption and production is very important for better managing water resources

# %% [markdown]
# # Machine Learning Modelling

# %% [markdown]
# Filter the unnecessary data

# %%
#filter the data and sum all of water conumption yearly
data['year'] = data['date'].dt.year
filter_model_data = data[(data["strata"] == "overall") & (data["sector"] == "domestic") & (data['age'] =='overall') & (data['ethnicity'] =='overall')& (data['sex'] =='both') ]
filter_model_data = filter_model_data.groupby('year').sum(numeric_only=True)

# Display the result
print(filter_model_data)
# Out:
#       water_consumption  proportion  population  water_production  \
# year
# 2003               4393      1309.3     23537.5             11047
# 2004               4772      1310.9     24014.9             11410
# 2005               4993      1330.2     24493.7             11563
# 2006               5025      1326.7     24972.4             12192
# 2007               5382      1282.4     25455.0             12826
# 2008               5466      1286.9     25938.8             13213
# 2009               5531      1302.7     26428.8             13493
# 2010               5602      1318.4     26840.6             14088
# 2011               5694      1321.4     27291.6             14563
# 2012               5873      1326.4     27729.5             15011
# 2013               6065      1332.1     28410.7             15498
# 2014               6268      1334.5     28890.3             15768
# 2015               6378      1330.6     29322.7             16159
# ...

# %% [markdown]
# **Split the data into 70% training and 30% testing and define the feature**

# %%
X = filter_model_data[['population', 'water_production']]  # Features (Population)
y = filter_model_data['water_consumption']  # Target (Water Consumption)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
# Initialize and train the model
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

# Predict water consumption for the test set
y_pred_lr = model_lr.predict(X_test)

# %%
# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred_lr)
mse = mean_squared_error(y_test, y_pred_lr)
r2 = r2_score(y_test, y_pred_lr)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 149.34098106758165
# Mean Squared Error: 36743.342322463526
# R-squared: 0.9608163198462736

# %%
# Plot true vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_lr, color='blue', label='Predicted vs Actual ')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='-', label='Ideal')
plt.xlabel('True Water Consumption (L)')
plt.ylabel('Predicted Water Consumption (L)')
plt.title('True vs Predicted Water Consumption')
plt.legend()
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the Random Forest Regressor model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
model_rf.fit(X_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(X_test)

# %%
# Evaluate the model
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f'Mean Absolute Error: {mae_rf}')
print(f'Mean Squared Error: {mse_rf}')
print(f'R-squared: {r2_rf}')
# Out:
# Mean Absolute Error: 271.7949999999999
# Mean Squared Error: 117605.46088333325
# R-squared: 0.8745836804082241

# %%
# Plot true vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_rf, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='-', label='Ideal')
plt.xlabel('True Water Consumption (L)')
plt.ylabel('Predicted Water Consumption (L)')
plt.title('True vs Predicted Water Consumption (in Thousand)')
plt.legend()
plt.show()

# %%
# Function to calculate metrics
import numpy as np
def evaluate_model(y_true, y_prediction):
    mae = mean_absolute_error(y_true, y_prediction)
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_prediction)
    return {"MAE": mae, "MSE": mse, "RMSE": rmse, "R2": r2}

# Metrics for Linear Regression
lr_metrics = evaluate_model(y_test, y_pred_lr)

# Metrics for Random Forest
rf_metrics = evaluate_model(y_test, y_pred_rf)

# Combine results into a DataFrame
results = pd.DataFrame([lr_metrics, rf_metrics], index=["Linear Regression", "Random Forest"])
print(results)
# Out:
#                           MAE            MSE        RMSE        R2
# Linear Regression  149.340981   36743.342322  191.685530  0.960816
# Random Forest      271.795000  117605.460883  342.936526  0.874584

# %% [markdown]
# ### LSTM

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Normalize the data to scale the values between 0 and 1 for better LSTM performance
df_lstm = filter_model_data[['water_production', 'population', 'water_consumption' ]]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df_lstm[['water_production', 'population', 'water_consumption']])

# Split data into features (X) and target (y)
X = scaled_data[:, :2]  # Features: water_production and population
y = scaled_data[:, 2]   # Target: water_consumption

# %%
# Function to create sequences for LSTM
def create_dataset(X, y, time_step=3):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])  # Target is the next value
    return np.array(X_seq), np.array(y_seq)

time_step = 3
X_seq, y_seq = create_dataset(X, y, time_step)

# Reshape X to be [samples, time steps, features]
X_seq = X_seq.reshape(X_seq.shape[0], X_seq.shape[1], X.shape[1])

# Split the data into training and testing sets (70% train, 30% test)
train_size = int(len(X_seq) * 0.7)
X_train, X_test = X_seq[:train_size], X_seq[train_size:]
y_train, y_test = y_seq[:train_size], y_seq[train_size:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units=100, return_sequences=False))
model_lstm.add(Dense(units=1))  # Output layer for regression

# Compile the model
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.2160 - val_loss: 0.6108
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 0.1938 - val_loss: 0.5475
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.1733 - val_loss: 0.4861
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1540 - val_loss: 0.4259
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1310 - val_loss: 0.3665
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1160 - val_loss: 0.3080
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0932 - val_loss: 0.2504
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0777 - val_loss: 0.1947
# Epoch 9/50
# ...

# %%
# Make predictions
y_pred_lstm = model_lstm.predict(X_test)

# Rescale predictions and actual values back to original scale
y_pred_rescaled = scaler.inverse_transform(
    np.hstack((X_test[:, -1, :], y_pred_lstm))
)[:, -1]

y_test_rescaled = scaler.inverse_transform(
    np.hstack((X_test[:, -1, :], y_test.reshape(-1, 1)))
)[:, -1]

# Evaluate the model
mse_lstm = mean_squared_error(y_test_rescaled, y_pred_rescaled)
r2_lstm = r2_score(y_test_rescaled, y_pred_rescaled)

print(f'Mean Squared Error: {mse_lstm}')
print(f'R-squared: {r2_lstm}')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f1e0b2bf5b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Mean Squared Error: 58806.3116822427
# R-squared: 0.6256446855737416

# %%
#plotting the True vs Predicted Water Consumption
years = df_lstm.index[-len(y_test_rescaled):]
plt.figure(figsize=(10, 6))
plt.plot(years, y_test_rescaled, color='blue', label='True Water Consumption')
plt.plot(years, y_pred_rescaled, color='red', label='Predicted Water Consumption')
plt.xlabel('Year')
plt.ylabel('Water Consumption (Thousand Liters)')
plt.title('True vs Predicted Water Consumption Over ')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA

# %%
# Split 70:30
train_size = int(len(filter_model_data) * 0.7)  # Use the correct DataFrame (filter_model_data) for splitting
train, test = filter_model_data.iloc[:train_size], filter_model_data.iloc[train_size:]  # Correctly split the intended DataFrame
train
# Out:
#       water_consumption  proportion  population  water_production  \
# year
# 2003               4393      1309.3     23537.5             11047
# 2004               4772      1310.9     24014.9             11410
# 2005               4993      1330.2     24493.7             11563
# 2006               5025      1326.7     24972.4             12192
# 2007               5382      1282.4     25455.0             12826
# 2008               5466      1286.9     25938.8             13213
# 2009               5531      1302.7     26428.8             13493
# 2010               5602      1318.4     26840.6             14088
# 2011               5694      1321.4     27291.6             14563
# 2012               5873      1326.4     27729.5             15011
# 2013               6065      1332.1     28410.7             15498
# 2014               6268      1334.5     28890.3             15768
# 2015               6378      1330.6     29322.7             16159
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
acf_original = plot_acf(train['water_consumption'])
pacf_original = plot_pacf(train['water_consumption'])

# %% [markdown]
# the above graphs shows, well known time series called random log, which is not stationary

# %%
from statsmodels.tsa.stattools import adfuller
adf_test = adfuller(train['water_consumption'])
print(f'p-value: {adf_test[1]}')
# Out:
# p-value: 0.9959231094166031

# %% [markdown]
# The above results also states that the time series is non-stationary becuase of large p-value

# %%
# Transform to Stationary: Differencing
df_water_train_diff = train['water_consumption'].diff().dropna()
df_water_train_diff.plot()
# Out:
# <Axes: xlabel='year'>

# %%
acf_diff = plot_acf(df_water_train_diff)
pacf_diff = plot_pacf(df_water_train_diff)

# %%
adf_test = adfuller(df_water_train_diff)
print(f'p-value: {adf_test[1]}')
# Out:
# p-value: 0.05786252535869132

# %% [markdown]
# After doing differencing the p-value is decrease into 0.05

# %%
from statsmodels.tsa.arima.model import ARIMA

# Define and fit the ARIMA model
model = ARIMA(train['water_consumption'], order=(1, 1, 1))
arima_result = model.fit()

# Summary of the model
print(arima_result.summary())

# Forecast on the test set
forecast = arima_result.forecast(steps=len(test))
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:      water_consumption   No. Observations:                   14
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -80.539
# Date:                Thu, 26 Dec 2024   AIC                            167.078
# Time:                        03:34:13   BIC                            168.773
# Sample:                             0   HQIC                           166.730
#                                  - 14
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9878      0.045     22.050      0.000       0.900       1.076
# ma.L1         -0.7942      0.381     -2.084      0.037      -1.541      -0.047
# sigma2      1.327e+04   7201.520      1.842      0.065    -847.205    2.74e+04
# ...

# %%
import matplotlib.pyplot as plt

# Plot test data and forecast
plt.figure(figsize=(10, 6))
plt.plot(test.index, test['water_consumption'], color='blue', label='True Water Consumption')
plt.plot(test.index, forecast, color='red', label='Predicted Water Consumption ')
plt.title('Test Data vs Forecast')
plt.xlabel('Time')
plt.ylabel('Water Consumption (Thousand Liters)')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Compute MSE
mse_arima = mean_squared_error(test['water_consumption'], forecast)
print(f"Mean Squared Error (MSE): {mse_arima}")

# Compute R-squared (R²)
r2_arima = r2_score(test['water_consumption'], forecast)
print(f"R-squared (R²): {r2_arima}")
# Out:
# Mean Squared Error (MSE): 39524.91403714603
# R-squared (R²): 0.7483882053001705

# %%
# Function to calculate metrics
import numpy as np
def evaluate_model(y_true, y_prediction):
    mae = mean_absolute_error(y_true, y_prediction)
    mse = mean_squared_error(y_true, y_prediction)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_prediction)
    return {"MAE": mae, "MSE": mse, "RMSE": rmse, "R2": r2}

# Metrics for LSTM
lstm_metrics = evaluate_model(y_test_rescaled, y_pred_rescaled)

# Metrics for ARIMA
arima_metrics = evaluate_model(test['water_consumption'], forecast)

# Combine results into a DataFrame
results = pd.DataFrame([lr_metrics, rf_metrics, lstm_metrics, arima_metrics], index=["Linear Regression", "Random Forest", "LSTM", "ARIMA"])
print(results)
# Out:
#                           MAE            MSE        RMSE        R2
# Linear Regression  149.340981   36743.342322  191.685530  0.960816
# Random Forest      271.795000  117605.460883  342.936526  0.874584
# LSTM               224.084465   58806.311682  242.500127  0.625645
# ARIMA              170.250560   39524.914037  198.808737  0.748388

# %% [markdown]
# # Result Evaluation and Interpretation

# %% [markdown]
# The evaluation is based on four metrics:
#
# *   Mean Absolute Error (MAE): Average magnitude of errors, where lower values are better.
# *   Mean Squared Error (MSE): Penalizes larger errors more, where lower values are better.
# *   Root Mean Squared Error (RMSE): The square root of MSE, providing error magnitudes in the same unit as the dependent variable. Lower values are better.
# *   R² (Coefficient of Determination): Explains the variance (accuracy) in the data; values closer to 1 indicate better fit.

# %% [markdown]
# 1. Linear Regression:
#   - Exceptional predictive accuracy for water usage in Malaysia.
#   - Low error metrics which indicate that the model consistently produces predictions close to the actual data points.
#   - The model explains 96.1% of the variance in water consumption, highlighting its strong ability to capture the relationship between population, water production and water consumption.
#   - This performance suggests that the underlying patterns in water consumption are largely linear, making Linear Regression a highly suitable choice for this dataset.
#
#   Limitations:
#   - Assumes a linear relationship between population, water production and water consumption which it may fail to capture more complex, non-linear patterns or events like sudden policy changes or global pandemic outbreaks.
#
#   Recommendations:
#   - Require regular assessment of its performance, especially if the nature of the predictors or water consumption patterns evolves over time.
#
#
# 2. Random Forest:
#   - Produced relatively high error metrics, indicating poorer predictive performance compared to other models.
#   - R² (0.875) explains only 87.5% of the variance, which is quite high and in contrast to the value obtained from the model’s error metrics.
#   - Its performance here suggests that it may not effectively handle the structure of this dataset.
#
#   Limitations:
#   - Possible overfitting, where the model focuses too closely on the training data, resulting in reduced generalizability to unseen data.
#   - Overly sensitive to noise or irrelevant features in the dataset based on the high metric errors. This could be a result of lacking optimal hyperparameter tuning.
#
#   Recommendations:
#   - Require further refinement by deriving additional predictors such as seasonal indexes, lagged variables, rolling averages, or interaction terms.
#   - Incorporating additional predictors, and optimizing hyperparameters such as tree depth, number of estimators, or minimum leaf size.
#   - Hybrid approaches that combine Random Forest with models adept at time-series prediction, such as ARIMA or LSTM, could yield improved results.
#
#
# 3. LSTM (Long Short-Term Memory):
#   - Produces intermediate MAE (224.084) and RMSE (242.500), with moderate MSE (58806.312) values.
#   - Low R² (0.627) suggests the model also struggles to explain the variance in the data.
#
#   Limitations:
#   - A data hungry model that requires large datasets to achieve high accuracy, which is not reflected here in our project.
#   - Highly sensitive where the model requires meticulous tuning of hyperparameters, while improper configurations can lead to suboptimal results.
#
#   Recommendations:
#   - Requires optimal implementation of larger datasets, refined preprocessing, and careful tuning for LSTM could outperform other models, especially for datasets with complex temporal patterns and dependencies.
#
# 4. ARIMA (AutoRegressive Integrated Moving Average):
#   - Demonstrated strong performance with the lowest MAE (170.251) and RMSE (198.809), and relatively low MSE (39,524.914).
#   - It indicates that the model is suitable for univariate time-series data which highlights ARIMA's effectiveness in capturing trends and seasonality in univariate time-series data.
#   - However, its moderate R² value (0.748) indicates that it explains 74.8% of the variance, which is lower than Linear Regression and Random Forest.
#
#   Limitations:
#   - Inability to handle external predictors using population and water consumption data unlike other models.
#   - Struggles with complex, non-linear relationships or external predictors.
#   - Less versatile compared to other models.
#
#   Recommendations:
#   - Hybrid approaches that combine other machine learning models such as SARIMA or ARIMAX could yield improved results.

# %% [markdown]
# **Conclusion**
#
# To summarize our findings, the **Linear Regression model is the best choice** for the regression modelling case as the model had produced high accuracy value while **LSTM performed the worst**. For scenarios where error metrics such as MAE and RMSE are prioritized, ARIMA is an excellent alternative compared to Random Forest. Although the Random Forest model had achieved higher accuracy than ARIMA, the model produced relatively high error metrics which makes the accuracy produced less reliable.
#
# From these results, we are able to provide recommendations for optimizing water resource allocation:
# - Prioritization based on variance insights. The R² scores indicate how well the models capture
# variability in the data. Linear Regression is the model with highest R² (0.961) value that is better suited for identifying key predictors influencing water usage, enabling resource prioritization for high-demand regions.
# - Other than that, we can utilize ARIMA for forecasting short-term water demand in regions with consistent patterns. This can help in proactive planning of water distribution, especially during peak demand periods.
#
# Our objectives for this project have been achieved where we are able to analyze water usage against the population in Malaysia by building four different machine learning models and evaluating the accuracy of the model using metric errors. Additionally, as stated in our business criteria in CRISP-DM, we managed to achieve at least 3 models with minimum 70% accuracy in predicting water production- Linear Regression, Random Forest and ARIMA; and also at least 3 models with moderate to low metric errors which is Linear Regression, ARIMA and LSTM models. Based on our results, we can say that the outcome of our project is a success.

# %% [markdown]
# # Members’ Contribution
